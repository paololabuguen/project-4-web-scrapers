# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import h5py

# %%
# Read the CSV file from the folder into a Pandas DataFram6e
df = pd.read_csv(
    Path("C:\\Users\\judy6\\Downloads\\mainDS.csv")
)
# Review the DataFrame
df.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# 0     2.498291                0.793724                            0
# 1     2.377215                0.974821                            0
# 2     4.316277                1.020075                            0
# 3     0.107020                0.749971                            0
# 4  1294.818751                0.368953                            0
#
#   Application Type  Last week Pay  Accounts Delinquent  \
# 0       INDIVIDUAL             49                    0
# 1       INDIVIDUAL            109                    0
# 2       INDIVIDUAL             66                    0
# 3       INDIVIDUAL             39                    0
# 4       INDIVIDUAL             18                    0
#
#    Total Collection Amount  Total Current Balance  \
# 0                       31                 311301
# 1                       53                 182610
# 2                       34                  89801
# 3                       40                   9189
# 4                      430                 126029
#
#    Total Revolving Credit Limit  Loan Status
# 0                          6619            0
# 1                         20885            0
# 2                         26155            0
# 3                         60214            0
# 4                         22579            0
#
# [5 rows x 35 columns]

# %%
columns_to_drop = ['Grade', 'Batch Enrolled', 'Sub Grade', 'Employment Duration', 'Application Type']

# Checking if the columns exist in the DataFrame before dropping them
columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#    Interest Rate  Home Ownership Verification Status Payment Plan  \
# 0      11.135007    176346.62670        Not Verified            n
# 1      12.237563     39833.92100     Source Verified            n
# 2      12.545884     91506.69105     Source Verified            n
# 3      16.731201    108286.57590     Source Verified            n
# 4      15.008300     44234.82545     Source Verified            n
#
#                 Loan Title  ...  Total Received Late Fee   Recoveries  \
# 0       Debt Consolidation  ...                 0.102055     2.498291
# 1       Debt consolidation  ...                 0.036181     2.377215
# 2       Debt Consolidation  ...                18.778660     4.316277
# 3       Debt consolidation  ...                 0.044131     0.107020
# 4  Credit card refinancing  ...                19.306646  1294.818751
#
#    Collection Recovery Fee  Collection 12 months Medical  Last week Pay  \
# 0                 0.793724                             0             49
# 1                 0.974821                             0            109
# 2                 1.020075                             0             66
# 3                 0.749971                             0             39
# 4                 0.368953                             0             18
#
#    Accounts Delinquent  Total Collection Amount  Total Current Balance  \
# 0                    0                       31                 311301
# 1                    0                       53                 182610
# 2                    0                       34                  89801
# 3                    0                       40                   9189
# 4                    0                      430                 126029
#
#   Total Revolving Credit Limit  Loan Status
# 0                         6619            0
# 1                        20885            0
# 2                        26155            0
# 3                        60214            0
# 4                        22579            0
#
# [5 rows x 30 columns]

# %%
y = df['Loan Status']


X = df.drop(columns='Loan Status')

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Loan Status, dtype: int64

# %%
# Reviewing the X variable DataFrame
X.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#    Interest Rate  Home Ownership Verification Status Payment Plan  \
# 0      11.135007    176346.62670        Not Verified            n
# 1      12.237563     39833.92100     Source Verified            n
# 2      12.545884     91506.69105     Source Verified            n
# 3      16.731201    108286.57590     Source Verified            n
# 4      15.008300     44234.82545     Source Verified            n
#
#                 Loan Title  ...  Total Received Interest  \
# 0       Debt Consolidation  ...              2929.646315
# 1       Debt consolidation  ...               772.769385
# 2       Debt Consolidation  ...               863.324396
# 3       Debt consolidation  ...               288.173196
# 4  Credit card refinancing  ...               129.239553
#
#    Total Received Late Fee   Recoveries  Collection Recovery Fee  \
# 0                 0.102055     2.498291                 0.793724
# 1                 0.036181     2.377215                 0.974821
# 2                18.778660     4.316277                 1.020075
# 3                 0.044131     0.107020                 0.749971
# 4                19.306646  1294.818751                 0.368953
#
#    Collection 12 months Medical  Last week Pay  Accounts Delinquent  \
# 0                             0             49                    0
# 1                             0            109                    0
# 2                             0             66                    0
# 3                             0             39                    0
# 4                             0             18                    0
#
#    Total Collection Amount Total Current Balance  Total Revolving Credit Limit
# 0                       31                311301                          6619
# 1                       53                182610                         20885
# 2                       34                 89801                         26155
# 3                       40                  9189                         60214
# 4                      430                126029                         22579
#
# [5 rows x 29 columns]

# %%
#Dropping columns with variable names
column = ['Verification Status']

# %%
df.drop(columns = column, inplace=True)

# %%
df.drop(columns = ["Payment Plan", "Loan Title", "ID"], inplace=True)

# %%
df.shape
# Out:
# (70366, 26)

# %%
df.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term  Interest Rate  \
# 0        10000          32236             12329.36286    59      11.135007
# 1         3609          11940             12191.99692    59      12.237563
# 2        28276           9311             21603.22455    59      12.545884
# 3        11170           6954             17877.15585    59      16.731201
# 4        16890          13226             13539.92667    59      15.008300
#
#    Home Ownership  Debit to Income  Delinquency - two years  \
# 0    176346.62670        16.284758                        1
# 1     39833.92100        15.412409                        0
# 2     91506.69105        28.137619                        0
# 3    108286.57590        18.043730                        1
# 4     44234.82545        17.209886                        1
#
#    Inquires - six months  Open Account  ...  Total Received Late Fee  \
# 0                      0            13  ...                 0.102055
# 1                      0            12  ...                 0.036181
# 2                      0            14  ...                18.778660
# 3                      0             7  ...                 0.044131
# 4                      3            13  ...                19.306646
#
#     Recoveries  Collection Recovery Fee  Collection 12 months Medical  \
# 0     2.498291                 0.793724                             0
# 1     2.377215                 0.974821                             0
# 2     4.316277                 1.020075                             0
# 3     0.107020                 0.749971                             0
# 4  1294.818751                 0.368953                             0
#
#   Last week Pay  Accounts Delinquent  Total Collection Amount  \
# 0            49                    0                       31
# 1           109                    0                       53
# 2            66                    0                       34
# 3            39                    0                       40
# 4            18                    0                      430
#
#    Total Current Balance  Total Revolving Credit Limit  Loan Status
# 0                 311301                          6619            0
# 1                 182610                         20885            0
# 2                  89801                         26155            0
# 3                   9189                         60214            0
# 4                 126029                         22579            0
#
# [5 rows x 26 columns]

# %%
# Checking the balance of our target values
target_balance = y.value_counts()
print(target_balance)
# Out:
# 0    64125
# 1     6241
# Name: Loan Status, dtype: int64

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(df.columns)
# Out:
# Index(['Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Interest Rate', 'Home Ownership', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Last week Pay', 'Accounts Delinquent',
#        'Total Collection Amount', 'Total Current Balance',
#        'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
df.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term  Interest Rate  \
# 0        10000          32236             12329.36286    59      11.135007
# 1         3609          11940             12191.99692    59      12.237563
# 2        28276           9311             21603.22455    59      12.545884
# 3        11170           6954             17877.15585    59      16.731201
# 4        16890          13226             13539.92667    59      15.008300
#
#    Home Ownership  Debit to Income  Delinquency - two years  \
# 0    176346.62670        16.284758                        1
# 1     39833.92100        15.412409                        0
# 2     91506.69105        28.137619                        0
# 3    108286.57590        18.043730                        1
# 4     44234.82545        17.209886                        1
#
#    Inquires - six months  Open Account  ...  Total Received Late Fee  \
# 0                      0            13  ...                 0.102055
# 1                      0            12  ...                 0.036181
# 2                      0            14  ...                18.778660
# 3                      0             7  ...                 0.044131
# 4                      3            13  ...                19.306646
#
#     Recoveries  Collection Recovery Fee  Collection 12 months Medical  \
# 0     2.498291                 0.793724                             0
# 1     2.377215                 0.974821                             0
# 2     4.316277                 1.020075                             0
# 3     0.107020                 0.749971                             0
# 4  1294.818751                 0.368953                             0
#
#   Last week Pay  Accounts Delinquent  Total Collection Amount  \
# 0            49                    0                       31
# 1           109                    0                       53
# 2            66                    0                       34
# 3            39                    0                       40
# 4            18                    0                      430
#
#    Total Current Balance  Total Revolving Credit Limit  Loan Status
# 0                 311301                          6619            0
# 1                 182610                         20885            0
# 2                  89801                         26155            0
# 3                   9189                         60214            0
# 4                 126029                         22579            0
#
# [5 rows x 26 columns]

# %%
print(df.dtypes)
# Out:
# Loan Amount                       int64
# Funded Amount                     int64
# Funded Amount Investor          float64
# Term                              int64
# Interest Rate                   float64
# Home Ownership                  float64
# Debit to Income                 float64
# Delinquency - two years           int64
# Inquires - six months             int64
# Open Account                      int64
# Public Record                     int64
# Revolving Balance                 int64
# Revolving Utilities             float64
# Total Accounts                    int64
# Initial List Status              object
# Total Received Interest         float64
# Total Received Late Fee         float64
# Recoveries                      float64
# Collection Recovery Fee         float64
# Collection 12 months Medical      int64
# Last week Pay                     int64
# Accounts Delinquent               int64
# Total Collection Amount           int64
# Total Current Balance             int64
# Total Revolving Credit Limit      int64
# Loan Status                       int64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Interest Rate', 'Home Ownership', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Last week Pay', 'Accounts Delinquent',
#        'Total Collection Amount', 'Total Current Balance',
#        'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
#Dropping columns with variable names
column_one = ['Initial List Status']

# %%
df.drop(columns = column_one, inplace=True)

# %%
print(df.dtypes)
# Out:
# Loan Amount                       int64
# Funded Amount                     int64
# Funded Amount Investor          float64
# Term                              int64
# Interest Rate                   float64
# Home Ownership                  float64
# Debit to Income                 float64
# Delinquency - two years           int64
# Inquires - six months             int64
# Open Account                      int64
# Public Record                     int64
# Revolving Balance                 int64
# Revolving Utilities             float64
# Total Accounts                    int64
# Total Received Interest         float64
# Total Received Late Fee         float64
# Recoveries                      float64
# Collection Recovery Fee         float64
# Collection 12 months Medical      int64
# Last week Pay                     int64
# Accounts Delinquent               int64
# Total Collection Amount           int64
# Total Current Balance             int64
# Total Revolving Credit Limit      int64
# Loan Status                       int64
# dtype: object

# %%
df.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term  Interest Rate  \
# 0        10000          32236             12329.36286    59      11.135007
# 1         3609          11940             12191.99692    59      12.237563
# 2        28276           9311             21603.22455    59      12.545884
# 3        11170           6954             17877.15585    59      16.731201
# 4        16890          13226             13539.92667    59      15.008300
#
#    Home Ownership  Debit to Income  Delinquency - two years  \
# 0    176346.62670        16.284758                        1
# 1     39833.92100        15.412409                        0
# 2     91506.69105        28.137619                        0
# 3    108286.57590        18.043730                        1
# 4     44234.82545        17.209886                        1
#
#    Inquires - six months  Open Account  ...  Total Received Late Fee  \
# 0                      0            13  ...                 0.102055
# 1                      0            12  ...                 0.036181
# 2                      0            14  ...                18.778660
# 3                      0             7  ...                 0.044131
# 4                      3            13  ...                19.306646
#
#     Recoveries  Collection Recovery Fee  Collection 12 months Medical  \
# 0     2.498291                 0.793724                             0
# 1     2.377215                 0.974821                             0
# 2     4.316277                 1.020075                             0
# 3     0.107020                 0.749971                             0
# 4  1294.818751                 0.368953                             0
#
#    Last week Pay  Accounts Delinquent  Total Collection Amount  \
# 0             49                    0                       31
# 1            109                    0                       53
# 2             66                    0                       34
# 3             39                    0                       40
# 4             18                    0                      430
#
#    Total Current Balance  Total Revolving Credit Limit  Loan Status
# 0                 311301                          6619            0
# 1                 182610                         20885            0
# 2                  89801                         26155            0
# 3                   9189                         60214            0
# 4                 126029                         22579            0
#
# [5 rows x 25 columns]

# %%
# 1. Identify non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['int64', 'float64']).columns

# %%
# 2. Print unique values in non-numeric columns
for column in non_numeric_columns:
    print(f"Column: {column}")
    print(df[column].value_counts())
    print()

# %%
# 3. Preprocess non-numeric data (e.g., using one-hot encoding for categorical data)
df = pd.get_dummies(df, columns=non_numeric_columns)

# %%
# 4. Verify that all columns are numeric
print(df.dtypes)
# Out:
# Loan Amount                       int64
# Funded Amount                     int64
# Funded Amount Investor          float64
# Term                              int64
# Interest Rate                   float64
# Home Ownership                  float64
# Debit to Income                 float64
# Delinquency - two years           int64
# Inquires - six months             int64
# Open Account                      int64
# Public Record                     int64
# Revolving Balance                 int64
# Revolving Utilities             float64
# Total Accounts                    int64
# Total Received Interest         float64
# Total Received Late Fee         float64
# Recoveries                      float64
# Collection Recovery Fee         float64
# Collection 12 months Medical      int64
# Last week Pay                     int64
# Accounts Delinquent               int64
# Total Collection Amount           int64
# Total Current Balance             int64
# Total Revolving Credit Limit      int64
# Loan Status                       int64
# dtype: object

# %%
# 5. Split your data into training and testing datasets
from sklearn.model_selection import train_test_split
X = df.drop('Loan Status', axis=1)
y = df['Loan Status'] #scale it 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
model = LogisticRegression(random_state=1, max_iter=500)

# Fit the model using training data
model.fit(X_train, y_train)
# Out:
# C:\Users\judy6\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=500, random_state=1)

# %%
X_train.columns
# Out:
# Index(['Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Interest Rate', 'Home Ownership', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Total Received Interest', 'Total Received Late Fee',
#        'Recoveries', 'Collection Recovery Fee', 'Collection 12 months Medical',
#        'Last week Pay', 'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit'],
#       dtype='object')

# %%
model.predict
# Out:
# <bound method LinearClassifierMixin.predict of LogisticRegression(max_iter=500, random_state=1)>

# %%
y_train
# Out:
# 40936    0
# 19933    0
# 43646    0
# 51349    0
# 17235    0
#         ..
# 49100    0
# 20609    0
# 21440    0
# 50057    0
# 5192     0
# Name: Loan Status, Length: 56292, dtype: int64

# %%
X_train
# Out:
#        Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 40936        32447          25859             26676.79948    59
# 19933        19650          19697             12243.53805    59
# 43646         4276           8054             12632.96699    59
# 51349        17080          21003             10328.79939    59
# 17235        13668          11785             27048.93599    58
# ...            ...            ...                     ...   ...
# 49100         7495          26718             13458.22586    59
# 20609         7020           7982             10331.03615    58
# 21440        26943          17382             26815.38957    58
# 50057         3683          27523             10684.66348    58
# 5192          6680          13688             10621.73514    59
#
#        Interest Rate  Home Ownership  Debit to Income  \
# 40936      11.318411     70670.28116        27.401729
# 19933      15.960165     84210.43814        22.237337
# 43646       9.088754     50292.07333        34.450419
# 51349      15.878837     65812.08451        19.379915
# 17235      12.172418     52838.08355        28.014912
# ...              ...             ...              ...
# 49100      13.497902     40314.58226         9.940739
# 20609       9.426243     47027.74428        38.604550
# 21440      11.891779    156643.18820        28.076497
# 50057      14.122177     50532.75658        17.990065
# 5192       10.855604     25733.37148        13.512838
#
#        Delinquency - two years  Inquires - six months  Open Account  ...  \
# 40936                        0                      0             8  ...
# 19933                        0                      0            12  ...
# 43646                        0                      0            30  ...
# 51349                        0                      0            30  ...
# 17235                        0                      0            16  ...
# ...                        ...                    ...           ...  ...
# 49100                        6                      0            10  ...
# 20609                        0                      0             9  ...
# 21440                        0                      0            14  ...
# 50057                        0                      1            35  ...
# 5192                         2                      1            16  ...
#
#        Total Received Interest  Total Received Late Fee   Recoveries  \
# 40936              1522.686473                 0.011706     2.071189
# 19933              2196.981252                 0.007458     1.212117
# 43646              1743.572511                 0.085539     7.616109
# 51349               265.995065                 0.061203     4.787983
# 17235              1028.402206                 0.027480     4.206280
# ...                        ...                      ...          ...
# 49100               861.998711                 0.004259     0.767896
# 20609              1346.209257                 0.093644  2791.451392
# 21440             12635.032470                32.555517     4.359588
# 50057              1865.852121                 0.039539     1.237202
# 5192               2960.920775                 0.029476     3.036323
#
#        Collection Recovery Fee  Collection 12 months Medical  Last week Pay  \
# 40936                 0.422254                             0             42
# 19933                 0.949642                             0             77
# 43646                 0.882179                             1             13
# 51349                 0.435003                             0             33
# 17235                 1.332674                             0             31
# ...                        ...                           ...            ...
# 49100                 0.540734                             0             46
# 20609                 0.995946                             0             86
# 21440                 0.834064                             0             76
# 50057                 0.877844                             1            159
# 5192                  0.464535                             0            108
#
#        Accounts Delinquent  Total Collection Amount  Total Current Balance  \
# 40936                    0                       41                 110437
# 19933                    0                       12                 166799
# 43646                    0                       47                 245650
# 51349                    0                       58                 293011
# 17235                    0                        6                 194231
# ...                    ...                      ...                    ...
# 49100                    0                       30                  11096
# 20609                    0                       44                 251567
# 21440                    0                       34                 114455
# 50057                    0                       33                 414800
# 5192                     0                       50                  19539
#
#        Total Revolving Credit Limit
# 40936                          5383
# 19933                         20978
# 43646                         70526
# 51349                         12291
# 17235                         22188
# ...                             ...
# 49100                         33513
# 20609                          2327
# 21440                         15168
# 50057                         12394
# 5192                          42077
#
# [56292 rows x 24 columns]

# %%
# Make a prediction using the testing data
predictions = model.predict(X_test)

# %%
# Print the balanced_accuracy score of the model
balanced_accuracy = balanced_accuracy_score(y_test, predictions)

# %%
# Generate a confusion matrix for the model
confusion = confusion_matrix(y_test, predictions)

# %%
# Print the classification report for the model
print("Balanced Accuracy Score:", balanced_accuracy)
print("Confusion Matrix:", confusion)
class_rep = classification_report(y_test, predictions)
print("Classification Report:", class_rep  )
# Out:
# Balanced Accuracy Score: 0.5
# Confusion Matrix: [[12827     0]
#  [ 1247     0]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     12827
#            1       0.00      0.00      0.00      1247
#
#     accuracy                           0.91     14074
#    macro avg       0.46      0.50      0.48     14074
# weighted avg       0.83      0.91      0.87     14074
# C:\Users\judy6\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\judy6\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\judy6\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_test_df = pd.DataFrame(X_test)
y_test_df = pd.DataFrame(y_test)

# Define file names for saving
x_test_filename = "X_test.csv"
y_test_filename = "y_test.csv"

# Save X test data to a CSV file
X_test_df.to_csv(x_test_filename, index=False)

# Save y test data to a CSV file
y_test_df.to_csv(y_test_filename, index=False)

print(f"X test data saved to {x_test_filename}")
print(f"y test data saved to {y_test_filename}")
# Out:
# X test data saved to X_test.csv
# y test data saved to y_test.csv

# %%
#converting the model into an h5 file
h5 = h5py.File("Linear_Regression.h5", "w")

# Create datasets to store your scaled data
h5.create_dataset("X_train_scaled", data=X_train_scaled)
h5.create_dataset("X_test_scaled", data=X_test_scaled)

# Close the HDF5 file
h5.close()
